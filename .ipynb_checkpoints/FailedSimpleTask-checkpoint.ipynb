# %%
import numpy as np
import h5py, pickle, torch, random
from matplotlib import pyplot as plt
from vit.models import SingleDecoder
from torch import nn

# %%
length = 20
n_batch = 64
dim = 128
n_output = 2
input_dim = 4

# %%
class MultiCrossEntropyLoss(nn.Module):
    def __init__(self):
        super().__init__()
    def forward(self, output, target):
        sm = torch.softmax(output, dim=-1)
        return -(target * torch.log(sm)).sum()

# %%
seed = 42
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.backends.cudnn.benchmark = False
torch.backends.cudnn.deterministic = True

# %%
model = SingleDecoder(input_dim=input_dim, length=length, dim=dim, num_classes=n_output+1, mlp_head=True, patch_size=1).cuda()
criterion = MultiCrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)

# %%
ls = 0
loss_save = []
for i in range(10000):
    optimizer.zero_grad()
    # Inputの0,2番が同期活動（Baseline+2）しているタイミングがあるならTargetの0番が1
    # Inputの1,3番が同期活動（Baseline+2）しているタイミングがあるならTargetの1番が1
    # 両方同期していないならTargetの2が1
    inputs = torch.rand((n_batch, 1, length, input_dim)).cuda()
    # Targetの0番と1番の結果を決める
    t = np.random.randint(2, size=(n_batch, 2)) == 1
    # 活動（Baseline+2）させる位置を決める
    r = np.array([[np.random.permutation(length) for _ in range(n_batch)] for _ in range(2)])
    for j in range(2):
        for k in range(n_batch):
            # Inputのj(= 0 or 1)番を2か所活動させる
            inputs[k, 0, r[j, k, :2], j] += 2
            # Targetのj(= 0 or 1)番が1のとき、Inputのj+2(= 2 or 3)番を1か所、Inputのj番と同じところを活動させる
            if t[k, j]:
                inputs[k, 0, r[j, k, 0], j+2] += 2
            # Targetのj(= 0 or 1)番が0のときは、Inputのj+2(= 2 or 3)番の、Inputのj番とは異なるところを1か所活動させる
            else:
                inputs[k, 0, r[j, k, 2], j+2] += 2
            # Inputのj+2(= 2 or 3)番を追加でもう1か所活動させる
            inputs[k, 0, r[j, k, -1], j+2] += 2

    # Targetを数値で表現する（dim=1方向の和が1になる）
    target = np.zeros((n_batch, n_output+1)).astype(np.float32)
    target[t[:, 0], 0] = 1
    target[t[:, 1], 1] = 1
    target[target.sum(axis=1) == 0, 2] = 1
    target /= target.sum(axis=1).reshape(-1, 1)
    target = torch.tensor(target).cuda()
    
    output = model(inputs)
    loss = criterion(output, target)
    loss.backward()
    optimizer.step()
    ls += loss.item()
    if (i + 1) % 100 == 0:
        print("iter: ", i+1, ", loss: ", ls)
        loss_save.append(ls)
        ls = 0
# Out:
# iter:  100 , loss:  6932.197547912598
# iter:  200 , loss:  6932.442626953125
# iter:  300 , loss:  6961.649108886719
# iter:  400 , loss:  6935.866859436035
# iter:  500 , loss:  6958.377059936523
# iter:  600 , loss:  6918.596389770508
# iter:  700 , loss:  6907.610900878906
# iter:  800 , loss:  6937.938766479492
# iter:  900 , loss:  6910.792945861816
# iter:  1000 , loss:  6931.376808166504
# iter:  1100 , loss:  6945.648956298828
# iter:  1200 , loss:  6912.1923904418945
# iter:  1300 , loss:  6935.618797302246
# iter:  1400 , loss:  6903.241523742676
# iter:  1500 , loss:  6935.847297668457
# iter:  1600 , loss:  6921.867729187012
# iter:  1700 , loss:  6919.082099914551
# iter:  1800 , loss:  6940.52091217041
# iter:  1900 , loss:  6914.505165100098
# iter:  2000 , loss:  6938.726303100586
# iter:  2100 , loss:  6932.784759521484
# iter:  2200 , loss:  6938.804420471191
# iter:  2300 , loss:  6924.462158203125
# iter:  2400 , loss:  6928.613426208496
# iter:  2500 , loss:  6937.510070800781
# iter:  2600 , loss:  6934.278205871582
# iter:  2700 , loss:  6930.444114685059
# iter:  2800 , loss:  6914.2221755981445
# iter:  2900 , loss:  6913.711318969727
# iter:  3000 , loss:  6947.350242614746
# iter:  3100 , loss:  6907.154479980469
# iter:  3200 , loss:  6935.514274597168
# iter:  3300 , loss:  6940.705924987793
# iter:  3400 , loss:  6924.431419372559
# iter:  3500 , loss:  6911.215476989746
# iter:  3600 , loss:  6928.804153442383
# iter:  3700 , loss:  6914.999855041504
# iter:  3800 , loss:  6922.873023986816
# iter:  3900 , loss:  6951.930694580078
# iter:  4000 , loss:  6936.062744140625
# iter:  4100 , loss:  6935.39884185791
# iter:  4200 , loss:  6923.182945251465
# iter:  4300 , loss:  6910.435104370117
# iter:  4400 , loss:  6951.270797729492
# iter:  4500 , loss:  6937.014015197754
# iter:  4600 , loss:  6927.116539001465
# iter:  4700 , loss:  6952.5502853393555
# iter:  4800 , loss:  6934.017532348633
# iter:  4900 , loss:  6958.7408447265625
# iter:  5000 , loss:  6928.490577697754
# iter:  5100 , loss:  6928.674102783203
# iter:  5200 , loss:  6914.326019287109
# iter:  5300 , loss:  6897.0930519104
# iter:  5400 , loss:  6919.587242126465
# iter:  5500 , loss:  6919.955238342285
# iter:  5600 , loss:  6941.449089050293
# iter:  5700 , loss:  6925.173599243164
# iter:  5800 , loss:  6914.059921264648
# iter:  5900 , loss:  6911.763610839844
# iter:  6000 , loss:  6944.703498840332
# iter:  6100 , loss:  6936.693893432617
# iter:  6200 , loss:  6909.7060546875
# iter:  6300 , loss:  6936.7369384765625
# iter:  6400 , loss:  6941.035400390625
# iter:  6500 , loss:  6954.441764831543
# iter:  6600 , loss:  6907.616714477539
# iter:  6700 , loss:  6929.415489196777
# iter:  6800 , loss:  6913.936187744141
# iter:  6900 , loss:  6920.664352416992
# iter:  7000 , loss:  6920.846328735352
# iter:  7100 , loss:  6924.191596984863
# iter:  7200 , loss:  6940.614196777344
# iter:  7300 , loss:  6935.15926361084
# iter:  7400 , loss:  6920.9400634765625
# iter:  7500 , loss:  6947.387954711914
# iter:  7600 , loss:  6945.2081298828125
# iter:  7700 , loss:  6918.806564331055
# iter:  7800 , loss:  6926.461387634277
# iter:  7900 , loss:  6921.853576660156
# iter:  8000 , loss:  6923.208694458008
# iter:  8100 , loss:  6931.2802810668945
# iter:  8200 , loss:  6939.814834594727
# iter:  8300 , loss:  6941.89444732666
# iter:  8400 , loss:  6927.937431335449
# iter:  8500 , loss:  6908.806968688965
# iter:  8600 , loss:  6915.5175704956055
# iter:  8700 , loss:  6911.029495239258
# iter:  8800 , loss:  6907.785057067871
# iter:  8900 , loss:  6949.1956787109375
# iter:  9000 , loss:  6915.501174926758
# iter:  9100 , loss:  6931.68741607666
# iter:  9200 , loss:  6899.367332458496
# iter:  9300 , loss:  6922.356689453125
# iter:  9400 , loss:  6917.473037719727
# iter:  9500 , loss:  6941.025238037109
# iter:  9600 , loss:  6938.791519165039
# iter:  9700 , loss:  6945.142295837402
# iter:  9800 , loss:  6937.898910522461
# iter:  9900 , loss:  6907.284927368164
# iter:  10000 , loss:  6909.433158874512

# %%
plt.plot(loss_save)
plt.xticks(np.arange(0, 120, 20), np.arange(0, 12000, 2000))
plt.ylabel("Multi Cross Entropy Loss")
plt.xlabel("Iteration")
# Out:
# Text(0.5, 0, 'Iteration')

# %%
# TargetとOutputの比較
fig, ax = plt.subplots(1, 2, figsize=(8, 6))
ax[0].pcolor(target.detach().cpu().numpy())
ax[0].set_title("Target")
ax[0].set_ylabel("Batch")
ax[0].set_xlabel("Target ID")
ax[0].set_xticks([0.5, 1.5, 2.5])
ax[0].set_xticklabels([1, 2, 3])
ax[1].pcolor(torch.softmax(output, dim=1).detach().cpu().numpy())
ax[1].set_title("Output")
ax[1].set_xticks([0.5, 1.5, 2.5])
ax[1].set_xticklabels([1, 2, 3])
ax[1].set_xlabel("Target ID")
# Out:
# Text(0.5, 0, 'Target ID')
